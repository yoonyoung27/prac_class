# %% [markdown]
# <a href="https://colab.research.google.com/github/yoonyoung27/prac_class/blob/main/01_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Open Colab
# For python
# https://colab.research.google.com/notebooks/intro.ipynb#recent=true
#
# For R
# https://colab.research.google.com/notebook#create=true&language=r

# %% [markdown]
# ###Mount google drive
# for python

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# for R
#
# ![image.png](data:image/png;base64,...)
# ⇩
# ![image.png](data:image/png;base64,...)
# ⇩
# ![image.png](data:image/png;base64,...)
# ⇩
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Save on github
# ![image.png](data:image/png;base64,...)
#
# ⇩
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Git
# '팀 개발을 위한 Git, GitHub 시작하기' 참고
# '(네이버 지식백과) 유닉스 리눅스 명령어 사전' https://terms.naver.com/list.naver?cid=59321&categoryId=59321
# '[GIT] 기본 환경 설정 및 작업 시작하기' https://www.tuwlab.com/ece/22210
#
# * cd directory name : 해당 디렉터리로 이동
#
# * git clone git repository address : 현 디렉터리에 깃 저장소 복사본 생성
#
# * ls : 현 디렉터리의 파일 정보 출력
#
# * git add file name : 로컬 저장소에 수정되거나 추가된 파일 임시 업데이트
#   -> git commit -m "explanation" : 수정 사항 기록
#   -> git push : 수정된 소스를 깃 저장소에 등록
#
# * git pull : 현 로컬 저장소에 등록된 깃 저장소의 소스를 로컬 저장소에 업데이트
#
# * mkdir directory name : 새 디렉터리 생성
#
# * git status : 현재 작업 상태 출력
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Markdown
# https://github.com/yoonyoung27/prac_class/blob/main/README.md
# * Markdown in Jupyter notebook
#   * Jupyter notebook have a cell for markdown
#   * LateX equations with $$ for mathematical expression
#
#   $$
#   \sum_{i=0}^n \frac{1}{X_i}
#   $$
#
# * R Markdown
#   * RStudio have R markdown page
#   * pandoc
#     * Mac
#     /Applications/RStudio.app/Contents/MacOS/pandoc
#     * Windows
#     c:\Program Files\RStudio\bin\pandoc
#   * YAML header
#   * Chunk options
#   https://yihui.name/knitr/options/#chunk_options
#   * In-line code
#
# * README.md in github

# %% [markdown]
# ####\*Open Markdown
# * R Markdown
#   * Open in R script page
#   library(rmarkdown)
#   render("_file name_")
#   * Open in R markdown page
# ![image.png](data:image/png;base64,...)
#
# * README.md in github
# https://guides.github.com/features/pages/
#
# ![image.png](data:image/png;base64,...)
#
# ⇩
#   ![image.png](data:image/png;base64,...)
#
# ⇩
#   ![image.png](data:image/png;base64,...)
