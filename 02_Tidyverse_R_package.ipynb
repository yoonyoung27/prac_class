# %% [markdown]
# <a href="https://colab.research.google.com/github/yoonyoung27/prac_class/blob/main/02_Tidyverse_R_package.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ✓ Open colab for R

# %% [markdown]
# ✓ Mount google drive
#
# ![image.png](data:image/png;base64,...)
# ⇩
# ![image.png](data:image/png;base64,...)
# ⇩
# ![image.png](data:image/png;base64,...)
# ⇩
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# \*Pipes [%>%]
#
# a tool for clearly expressing a sequence of multiple operations

# %% [markdown]
# without pipes

# %%
summary(cars)
# Out:
#      speed           dist
#  Min.   : 4.0   Min.   :  2.00
#  1st Qu.:12.0   1st Qu.: 26.00
#  Median :15.0   Median : 36.00
#  Mean   :15.4   Mean   : 42.98
#  3rd Qu.:19.0   3rd Qu.: 56.00
#  Max.   :25.0   Max.   :120.00

# %% [markdown]
# with pipes

# %%
cars %>% summary()
# Out:
#      speed           dist
#  Min.   : 4.0   Min.   :  2.00
#  1st Qu.:12.0   1st Qu.: 26.00
#  Median :15.0   Median : 36.00
#  Mean   :15.4   Mean   : 42.98
#  3rd Qu.:19.0   3rd Qu.: 56.00
#  Max.   :25.0   Max.   :120.00

# %% [markdown]
# #Tidyverse
# collection of R packages designed for data science
#
# https://r4ds.had.co.nz/
#
# http://hadley.nz/

# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.1     ✔ dplyr   1.0.5
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# ##Dplyr
# a package for data manipulation

# %% [markdown]
# \*nycflights13
#
# dataset on flights departing New York City in 2013.

# %%
install.packages("nycflights13")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(nycflights13)
flights[1:5,]
?flights
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 05:00:00
# 3 2013-01-01 05:00:00
# 4 2013-01-01 05:00:00
# 5 2013-01-01 06:00:00

# %% [markdown]
# - __< int >__ stands for integers.
# - __< dbl >__ stands for doubles, or real numbers.
# - __< chr >__ stands for character vectors, or strings.
# - __< dttm >__ stands for date-times (a date + a time).
# - __< lgl >__ stands for logical, vectors that contain only TRUE or FALSE.
# - __< fctr >__ stands for factors, which R uses to represent categorical variables with fixed possible values.
# - __< date >__ stands for dates.

# %% [markdown]
# ###①filter() - rows
# filter rows by their values

# %%
filter(flights, month == 1, day == 1) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %% [markdown]
# - __< head() >__ show first 6 objects
# - __< head(n) >__ show first n objects

# %%
flights %>% filter(month == 1 & day == 1 & dest %in% c('ORD','LAS')) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   554      558            -4        740      728
# 2 2013 1     1   558      600            -2        753      745
# 3 2013 1     1   559      600            -1        854      902
# 4 2013 1     1   608      600             8        807      735
# 5 2013 1     1   629      630            -1        824      810
# 6 2013 1     1   651      655            -4        936      942
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 12        UA      1696   N39463  EWR    ORD  150       719     5    58
# 2  8        AA       301   N3ALAA  LGA    ORD  138       733     6     0
# 3 -8        UA      1187   N76515  EWR    LAS  337      2227     6     0
# 4 32        MQ      3768   N9EAMQ  EWR    ORD  139       719     6     0
# 5 14        AA       303   N3CYAA  LGA    ORD  140       733     6    30
# ...

# %% [markdown]
# - __<x %in% y>__ select every row where x is one of the values in y
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###②arrange() - rows
# reorder the rows

# %%
arrange(flights, year, month, day) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
arrange(flights, desc(dep_delay)) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1      9   641      900           1301      1242     1530
# 2 2013 6     15  1432     1935           1137      1607     2120
# 3 2013 1     10  1121     1635           1126      1239     1810
# 4 2013 9     20  1139     1845           1014      1457     2210
# 5 2013 7     22   845     1600           1005      1044     1815
# 6 2013 4     10  1100     1900            960      1342     2211
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 1272      HA        51   N384HA  JFK    HNL  640      4983      9    0
# 2 1127      MQ      3535   N504MQ  JFK    CMH   74       483     19   35
# 3 1109      MQ      3695   N517MQ  EWR    ORD  111       719     16   35
# 4 1007      AA       177   N338AA  JFK    SFO  354      2586     18   45
# 5  989      MQ      3075   N665MQ  JFK    CVG   96       589     16    0
# ...

# %% [markdown]
# - __< desc() >__ reorder in descending order

# %% [markdown]
# ###③select() - columns
# select columns  by their names

# %%
select(flights, year, month, day) %>% head()

#select(flights, year:day) %>% head() ;위와 같은 식
# Out:
#   year month day
# 1 2013 1     1
# 2 2013 1     1
# 3 2013 1     1
# 4 2013 1     1
# 5 2013 1     1
# 6 2013 1     1

# %%
select(flights, -(year:day)) %>% head()
# Out:
#   dep_time sched_dep_time dep_delay arr_time sched_arr_time arr_delay carrier
# 1 517      515             2         830      819            11       UA
# 2 533      529             4         850      830            20       UA
# 3 542      540             2         923      850            33       AA
# 4 544      545            -1        1004     1022           -18       B6
# 5 554      600            -6         812      837           -25       DL
# 6 554      558            -4         740      728            12       UA
#   flight tailnum origin dest air_time distance hour minute time_hour
# 1 1545   N14228  EWR    IAH  227      1400     5    15     2013-01-01 05:00:00
# 2 1714   N24211  LGA    IAH  227      1416     5    29     2013-01-01 05:00:00
# 3 1141   N619AA  JFK    MIA  160      1089     5    40     2013-01-01 05:00:00
# 4  725   N804JB  JFK    BQN  183      1576     5    45     2013-01-01 05:00:00
# ...

# %% [markdown]
# - __< -x >__ except x

# %%
select(flights, starts_with("arr")) %>% head()
# Out:
#   arr_time arr_delay
# 1  830      11
# 2  850      20
# 3  923      33
# 4 1004     -18
# 5  812     -25
# 6  740      12

# %% [markdown]
# - __<starts_with("abc")>__ matches names that begin with “abc”.
# - __<ends_with("xyz")>__ matches names that end with “xyz”.
# - __<contains("ijk")>__ matches names that contain “ijk”.
# - __<num_range("x", 1:3)>__ matches x1, x2 and x3.

# %%
select(flights, time_hour, air_time, everything()) %>% head()
# Out:
#   time_hour           air_time year month day dep_time sched_dep_time dep_delay
# 1 2013-01-01 05:00:00 227      2013 1     1   517      515             2
# 2 2013-01-01 05:00:00 227      2013 1     1   533      529             4
# 3 2013-01-01 05:00:00 160      2013 1     1   542      540             2
# 4 2013-01-01 05:00:00 183      2013 1     1   544      545            -1
# 5 2013-01-01 06:00:00 116      2013 1     1   554      600            -6
# 6 2013-01-01 05:00:00 150      2013 1     1   554      558            -4
#   arr_time sched_arr_time arr_delay carrier flight tailnum origin dest distance
# 1  830      819            11       UA      1545   N14228  EWR    IAH  1400
# 2  850      830            20       UA      1714   N24211  LGA    IAH  1416
# 3  923      850            33       AA      1141   N619AA  JFK    MIA  1089
# 4 1004     1022           -18       B6       725   N804JB  JFK    BQN  1576
# ...

# %% [markdown]
# - __<everything()>__

# %% [markdown]
# ###④mutate() - columns
# create new variables with existing variables

# %%
flights %>% 
    select(year:day, ends_with("delay"), distance, air_time) %>% 
    mutate(gain = dep_delay - arr_delay,
              hours = air_time / 60,
              gain_per_hour = gain / hours) %>% head()
# Out:
#   year month day dep_delay arr_delay distance air_time gain hours
# 1 2013 1     1    2         11       1400     227       -9  3.783333
# 2 2013 1     1    4         20       1416     227      -16  3.783333
# 3 2013 1     1    2         33       1089     160      -31  2.666667
# 4 2013 1     1   -1        -18       1576     183       17  3.050000
# 5 2013 1     1   -6        -25        762     116       19  1.933333
# 6 2013 1     1   -4         12        719     150      -16  2.500000
#   gain_per_hour
# 1  -2.378855
# 2  -4.229075
# 3 -11.625000
# 4   5.573770
# 5   9.827586
# 6  -6.400000

# %% [markdown]
# ####\* rename()

# %%
colnames(flights)
# Out:
#  [1] "year"           "month"          "day"            "dep_time"
#  [5] "sched_dep_time" "dep_delay"      "arr_time"       "sched_arr_time"
#  [9] "arr_delay"      "carrier"        "flight"         "tailnum"
# [13] "origin"         "dest"           "air_time"       "distance"
# [17] "hour"           "minute"         "time_hour"

# %%
rename(flights, tail_num = tailnum) %>% head

#colnames(flights)[12] = tailnum ;위와 같은 식
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tail_num origin dest air_time distance hour minute
# 1  11       UA      1545   N14228   EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211   LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA   JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB   JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN   LGA    ATL  116       762     6     0
# ...

# %% [markdown]
# ###⑤summarise()
# grouped summaries

# %%
flights %>% group_by(year, month, day) %>% 
summarise(delay = mean(dep_delay, na.rm = TRUE)) %>% head()
# Out:
# `summarise()` has grouped output by 'year', 'month'. You can override using the `.groups` argument.
#   year month day delay
# 1 2013 1     1   11.548926
# 2 2013 1     2   13.858824
# 3 2013 1     3   10.987832
# 4 2013 1     4    8.951595
# 5 2013 1     5    5.732218
# 6 2013 1     6    7.148014

# %% [markdown]
# - __<group_by()>__ grouping

# %% [markdown]
# ##Ggplot
# a package for data visualization

# %% [markdown]
# *mpg
#
# dataset

# %%
?mpg

# %% [markdown]
# ###①geom_()

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point()

#ggplot(data = mpg) + 
#  geom_point(mapping = aes(x = displ, y = hwy)) ;위와 다른 식 because mapping in ggplot() declare global mapping information
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = class)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# - __< color(or 'size', 'alpha', 'shape') = x >__ color(or 'size', 'alpha', 'shape') represents x

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point() + 
  geom_line()
# Out:
# plot without title

# %% [markdown]
# - __<geom_line()>__ add graphical layers
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###②facet_()
# visualize multiple graphs

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_wrap(~ class, nrow = 2)
# Out:
# plot without title

# %% [markdown]
# ###③theme()
# better visualization

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + theme_bw() +
  theme(axis.line= element_line(size=.8, colour = "black"),
        panel.grid.minor = element_blank(),
        panel.border = element_blank(),
        text = element_text(size = 25))
# Out:
# plot without title

# %% [markdown]
# ##\* Something useful

# %% [markdown]
# ###① boxplot __VS__ violinplot
# when the data distribution is not following the normal distribution

# %%
diamonds %>% ggplot(aes(cut, price)) + geom_boxplot()
diamonds %>% ggplot(aes(cut, price)) + geom_violin()
# Out:
# plot without title
# plot without title

# %% [markdown]
# ###② pie chart VS bar plot
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###③ effective 2D visualization with t_SNE and UMAP
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Tidyr
# a package for data cleaning (most built-in R functions work with vectors of values)
#
# #####* Rule for tidy data
#
# * Every column is variable
# * Every row is an observation
# * Every cell is a single value

# %% [markdown]
# ###①Pivoting

# %% [markdown]
# ####①.1 pivot_longer()

# %% [markdown]
# \*table4a, table4b
# The dataset on which one variable is spread across multiple columns

# %%
table4a
# Out:
#   country     1999   2000
# 1 Afghanistan    745   2666
# 2 Brazil       37737  80488
# 3 China       212258 213766

# %%
table4b
# Out:
#   country     1999       2000
# 1 Afghanistan   19987071   20595360
# 2 Brazil       172006362  174504898
# 3 China       1272915272 1280428583

# %%
help(pivot_longer)

# %%
tidy4a <- table4a %>%
pivot_longer(c('1999', '2000'), names_to = "year", values_to = "cases")
tidy4a
# Out:
#   country     year cases
# 1 Afghanistan 1999    745
# 2 Afghanistan 2000   2666
# 3 Brazil      1999  37737
# 4 Brazil      2000  80488
# 5 China       1999 212258
# 6 China       2000 213766

# %%
tidy4b <- table4b %>%
pivot_longer(c('1999', '2000'), names_to = "year", values_to = "population")
tidy4b
# Out:
#   country     year population
# 1 Afghanistan 1999   19987071
# 2 Afghanistan 2000   20595360
# 3 Brazil      1999  172006362
# 4 Brazil      2000  174504898
# 5 China       1999 1272915272
# 6 China       2000 1280428583

# %%
?left_join
left_join(tidy4a, tidy4b)
# Out:
# Joining, by = c("country", "year")
#   country     year cases  population
# 1 Afghanistan 1999    745   19987071
# 2 Afghanistan 2000   2666   20595360
# 3 Brazil      1999  37737  172006362
# 4 Brazil      2000  80488  174504898
# 5 China       1999 212258 1272915272
# 6 China       2000 213766 1280428583

# %% [markdown]
# * __<left_join(x,y)>__ Add columns from y to x matching rows based on the keys of x

# %% [markdown]
# ####①.2 pivot_wider()

# %% [markdown]
# \*table2
# The dataset on which one observation is scattered across multiple rows

# %%
table2
# Out:
#    country     year type       count
# 1  Afghanistan 1999 cases             745
# 2  Afghanistan 1999 population   19987071
# 3  Afghanistan 2000 cases            2666
# 4  Afghanistan 2000 population   20595360
# 5  Brazil      1999 cases           37737
# 6  Brazil      1999 population  172006362
# 7  Brazil      2000 cases           80488
# 8  Brazil      2000 population  174504898
# 9  China       1999 cases          212258
# 10 China       1999 population 1272915272
# 11 China       2000 cases          213766
# 12 China       2000 population 1280428583

# %%
help(pivot_wider)

# %%
table2 %>%
pivot_wider(names_from = type, values_from = count)
# Out:
#   country     year cases  population
# 1 Afghanistan 1999    745   19987071
# 2 Afghanistan 2000   2666   20595360
# 3 Brazil      1999  37737  172006362
# 4 Brazil      2000  80488  174504898
# 5 China       1999 212258 1272915272
# 6 China       2000 213766 1280428583

# %% [markdown]
# ###② Seperating and uniting

# %% [markdown]
# ####②.1 seperate()

# %% [markdown]
# \*table3
# The dataset on which one column contains two variables

# %%
table3
# Out:
#   country     year rate
# 1 Afghanistan 1999 745/19987071
# 2 Afghanistan 2000 2666/20595360
# 3 Brazil      1999 37737/172006362
# 4 Brazil      2000 80488/174504898
# 5 China       1999 212258/1272915272
# 6 China       2000 213766/1280428583

# %%
help(separate)

# %% [markdown]
# * __<[^[:alnum:]]+>__ One kind of regular expression. Any string that are not numbers

# %%
table3 %>%
separate(rate, into = c("cases", "population"), sep="/") %>%
mutate(cases = as.numeric(cases), population = as.numeric(population))  # seperate()의 결과값 데이터 유형은 character이므로 as.numeric을 통해 숫자로 바꾼다
# Out:
#   country     year cases  population
# 1 Afghanistan 1999    745   19987071
# 2 Afghanistan 2000   2666   20595360
# 3 Brazil      1999  37737  172006362
# 4 Brazil      2000  80488  174504898
# 5 China       1999 212258 1272915272
# 6 China       2000 213766 1280428583

# %% [markdown]
# ####②.2 unite()

# %% [markdown]
# \*table5
# the dataset on which single variable is spread across multiple columns

# %%
table5
# Out:
#   country     century year rate
# 1 Afghanistan 19      99   745/19987071
# 2 Afghanistan 20      00   2666/20595360
# 3 Brazil      19      99   37737/172006362
# 4 Brazil      20      00   80488/174504898
# 5 China       19      99   212258/1272915272
# 6 China       20      00   213766/1280428583

# %%
help(unite)

# %%
table5 %>%
unite(new, century, year, sep = "")
# Out:
#   country     new  rate
# 1 Afghanistan 1999 745/19987071
# 2 Afghanistan 2000 2666/20595360
# 3 Brazil      1999 37737/172006362
# 4 Brazil      2000 80488/174504898
# 5 China       1999 212258/1272915272
# 6 China       2000 213766/1280428583

# %% [markdown]
# ##Purrr
# a package for looping patterns over a vector

# %% [markdown]
# ###① map()

# %%
?map()

df %>% map(mean)       # df는 아래의 Example data에서 정의
# df %>% map(~mean(.)) ; 위와 같은 식
df %>% map_dbl(mean)
# Out:
# $a
# [1] -0.3491702
#
# $b
# [1] -0.01915807
#
# $c
# [1] -0.07594669
#
# $d
# [1] 0.04373204
#           a           b           c           d
# -0.34917022 -0.01915807 -0.07594669  0.04373204

# %% [markdown]
# * __<~ftn(.)>__ put the vector of df in the location of .
# * output
#  * map() output as a list
#  * map_lgl() output as a logical vector
#  * map_int() output as an integer vector
#  * map_dbl() output as a double vector
#  * map_chr() output as a character vector

# %%
f1 <- function(df) {
    lm(mpg ~ wt, data = df)
    }
mtcars %>%
split(.$cyl) %>%
map(f1)

#mtcars %>%
#split(.$cyl) %>%
#map(function(df) lm(mpg ~ wt, data = df)) ; 위와 같은 식

#mtcars %>%
#split(.$cyl) %>%
#map(~lm(mpg ~ wt, data = .)) ; 위와 같은 식

mtcars %>%
split(.$cyl) %>%
map(~lm(mpg ~ wt, data = .)) %>%
map(summary) %>%
map_dbl(~.$r.squared)

#mtcars %>%
#split(.$cyl) %>%
#map(~lm(mpg ~ wt, data = .)) %>%
#map(summary) %>%
#map_dbl('r.squared') ; 위와 같은 식

x <- list(list(1, 2, 3), list(4, 5, 6), list(7, 8, 9))
x %>% map_dbl(2)
# Out:
# $`4`
#
# Call:
# lm(formula = mpg ~ wt, data = df)
#
# Coefficients:
# (Intercept)           wt
#      39.571       -5.647
#
#
# $`6`
#
# Call:
# lm(formula = mpg ~ wt, data = df)
#
# Coefficients:
# (Intercept)           wt
#       28.41        -2.78
#
#
# $`8`
#
# Call:
# lm(formula = mpg ~ wt, data = df)
#
# Coefficients:
# (Intercept)           wt
#      23.868       -2.192
#         4         6         8
# 0.5086326 0.4645102 0.4229655
# [1] 2 5 8

# %% [markdown]
# * Application
#  * define a function in a map function
#  * extract a component

# %% [markdown]
# ##\*for_loops
# ####3 components
# * The output
#
# >allocate sufficient space for the output
#
# * The sequence
#
# >what to loop over
#
# * The body
#
# >the code that does the work

# %% [markdown]
# \*Example data

# %%
df <- tibble(
    a = rnorm(10),
    b = rnorm(10),
    c = rnorm(10),
    d = rnorm(10)
    )
class(df)
df
# Out:
# [1] "tbl_df"     "tbl"        "data.frame"
#    a           b           c          d
# 1  -0.66759451  0.17521164  1.5952762  0.7150006
# 2   0.06850362 -0.92825886  2.0343152  0.6344354
# 3   1.01356722 -0.08623014  0.4412352 -1.0098158
# 4   0.61489972  1.03738294 -0.1160845 -0.8724600
# 5  -0.52009318  0.08901091 -0.3054392  0.2361849
# 6  -1.76552379  0.53982692 -1.5899911 -0.3579429
# 7   0.44259467  0.56017302  0.7931306 -0.4108368
# 8  -0.53035380 -0.03010058 -0.9121592 -0.1839346
# 9  -1.54338495 -0.92391527  0.2689075 -0.8411438
# 10 -0.60431718 -0.62468126 -2.9686576  2.5278335

# %% [markdown]
# * __<rnorm(n)>__ n random numbers from normal distribution

# %%
output <- vector("double", ncol(df))  # 1. output
for (i in seq_along(df)) {            # 2. sequence
    output[[i]] <- median(df[[i]])    # 3. body
    }
output
# Out:
# [1] -0.52522349  0.02945516  0.07641148 -0.27093873

# %%
install.packages("rbenchmark")
library(rbenchmark)

simple1 <- function(n) {
    output <- vector("double", n)
    for(i in 1:n)
    output[i] = i
    return(output)
    }

simple2 <- function(n) {
    output <- c()
    for(i in 1:n)
    output = c(output, i)
    return(output)
    }

simple1(3)
simple2(3)

output1 <- vector("double", 4)
output2 <- c()
print(output1)
output2

benchmark("fc1"=simple1(1000),
          "fc2"=simple2(1000),
          replications=100,
          columns=c('test', 'elapsed', 'replications'))  # 사전에 vector 저장 공간을 할당해 해당 공간에 output을 저장하는 방법이 output이 나올때마다 저장 공간을 하나하나 할당하는 방법보다 효율적이다
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# [1] 1 2 3
# [1] 1 2 3
# [1] 0 0 0 0
# NULL
#   test elapsed replications
# 1 fc1  0.009   100
# 2 fc2  0.235   100

# %%
?function()

col_mean <- function(df) {
    output <- vector("double", ncol(df))
    for (i in seq_along(df)) {
        output[[i]] <- mean(df[[i]])
        }
    output
}

col_mean(df)

col_summary <- function(df, fun) {
    out <- vector("double", length(df))
    for (i in seq_along(df)) {
        out[i] <- fun(df[[i]])
        }
    out
}

col_summary(df, mean)
col_summary(df, median)
col_summary(df, sd)
# Out:
# [1] -0.34917022 -0.01915807 -0.07594669  0.04373204
# [1] -0.34917022 -0.01915807 -0.07594669  0.04373204
# [1] -0.52522349  0.02945516  0.07641148 -0.27093873
# [1] 0.8974389 0.6523610 1.4832968 1.0624664

# %% [markdown]
# * Application
#  * wrap up for_loops in a function
#  * make function as a variable

# %% [markdown]
# \* functional programming __VS__ for_loops

# %%
n_len = 10
gen1 <- function(n_len) {
    rep(10,n_len) %>% map(~rnorm(.))
    }

gen2 <- function(n_len) {
    df2 <- vector(mode = "list", length = n_len)
    for (i in 1:n_len)
    df2[[i]] <- rnorm(10)
    df2
    }

gen3 <- function(n_len) {
    lapply(rep(10,n_len), rnorm )
    }

benchmark("fc1"=gen1(1000),
          "fc2"=gen2(1000),
          "fc3"=gen3(1000),
          replications=100,
          columns=c('test', 'elapsed', 'replications'))
# Out:
#   test elapsed replications
# 1 fc1  0.745   100
# 2 fc2  0.426   100
# 3 fc3  0.437   100

# %% [markdown]
# * apply() and lapply() can be alternatives of map()
# * use the one that you are familiar with
# * but functional programming is memory efficient by not saving internal calculations. Easier to understand if you get used to it.
